# %%
import yfinance as yf

# Microsoft(MSFT)에 대한 Ticker 객체 생성
msft = yf.Ticker("MSFT")

# Ticker 객체의 정보 출력(.py에서 실행할 때는 print(msft.info)로 사용)
display(msft.info)
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': "Microsoft Corporation develops and supports software, services, devices, and solutions worldwide. The company's Productivity and Business Processes segment offers Microsoft 365 Commercial, Enterprise Mobility + Security, Windows Commercial, Power BI, Exchange, SharePoint, Microsoft Teams, Security and Compliance, and Copilot; Microsoft 365 Commercial products, such as Windows Commercial on-premises and Office licensed services; Microsoft 365 Consumer products and cloud services, such as Microsoft 365 Consumer subscriptions, Office licensed on-premises, and other consumer services; LinkedIn; Dynamics products and cloud services, such as Dynamics 365, cloud-based applications, and on-premises ERP and CRM applications. Its Intelligent Cloud segment provides Server products and cloud services, such as Azure and other cloud services, GitHub, Nuance Healthcare, virtual desktop offerings, and other cloud services; Server products, including SQL and Windows Server, Visual Studio and System Center related Client Access Licenses, and other on-premises offerings; Enterprise and partner services, including Enterprise Support and Nuance professional Services, Industry Solutions, Microsoft Partner Network, and Learning Experience. The company's Personal Computing segment provides Windows and Devices, such as Windows OEM licensing and Devices and Surface and PC accessories; Gaming services and solutions, such as Xbox hardware, content, and services, first- and third-party content Xbox Game Pass, subscriptions, and Cloud Gaming, advertising, and other cloud services; search and news advertising services, such as Bing and Copilot, Microsoft News and Edge, and third-party affiliates. It sells its products through OEMs, distributors, and resellers; and online and retail stores. The company was founded in 1975 and is headquartered in Redmond, Washington.",
#  'fullTimeEmployees': 228000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Satya  Nadella',
#    'age': 58,
#    'title': 'Chairman & CEO',
#    'yearBorn': 1967,
#    'fiscalYear': 2025,
#    'totalPay': 12251294,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bradford L. Smith LCA',
#    'age': 66,
#    'title': 'President & Vice Chairman',
#    'yearBorn': 1959,
#    'fiscalYear': 2025,
#    'totalPay': 4532750,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Amy E. Hood',
#    'age': 53,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2025,
#    'totalPay': 4444191,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Takeshi  Numoto',
#    'age': 54,
#    'title': 'Executive VP & Chief Marketing Officer',
#    'yearBorn': 1971,
#    'fiscalYear': 2025,
#    'totalPay': 2871250,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Judson B. Althoff',
#    'age': 52,
#    'title': 'Executive VP & CEO of Commercial Business',
#    'yearBorn': 1973,
#    'fiscalYear': 2025,
#    'totalPay': 4490115,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Carolina  Dybeck Happe',
#    'age': 53,
#    'title': 'Executive VP & COO',
#    'yearBorn': 1972,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Alice L. Jolla',
#    'age': 59,
#    'title': 'Corporate VP & Chief Accounting Officer',
#    'yearBorn': 1966,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Matthew  Kerner',
#    'title': 'CTO & Corporate VP of Worldwide Sales and Solutions',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Jonathan  Neilson',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jonathan M. Palmer',
#    'title': 'Corporate Vice President & Chief Legal Officer',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 9,
#  'boardRisk': 8,
#  'compensationRisk': 5,
#  'shareHolderRightsRisk': 2,
#  'overallRisk': 5,
#  'governanceEpochDate': 1768176000,
#  'compensationAsOfEpochDate': 1767139200,
#  'irWebsite': 'http://www.microsoft.com/investor/default.aspx',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 465.95,
#  'open': 465.305,
#  'dayLow': 462.0,
#  'dayHigh': 470.81,
#  'regularMarketPreviousClose': 465.95,
#  'regularMarketOpen': 465.305,
#  'regularMarketDayLow': 462.0,
#  'regularMarketDayHigh': 470.81,
#  'dividendRate': 3.64,
#  'dividendYield': 0.78,
#  'exDividendDate': 1771459200,
#  'payoutRatio': 0.2361,
#  'fiveYearAvgDividendYield': 0.8,
#  'beta': 1.073,
#  'trailingPE': 33.430347,
#  'forwardPE': 25.150465,
#  'volume': 7716011,
#  'regularMarketVolume': 7716011,
#  'averageVolume': 25197300,
#  'averageVolume10days': 28363580,
#  'averageDailyVolume10Day': 28363580,
#  'bid': 466.02,
#  'ask': 470.69,
#  'bidSize': 4,
#  'askSize': 1,
#  'marketCap': 3496301297664,
#  'fiftyTwoWeekLow': 344.79,
#  'fiftyTwoWeekHigh': 555.45,
#  'allTimeHigh': 555.45,
#  'allTimeLow': 0.088542,
#  'priceToSalesTrailing12Months': 11.89979,
#  'fiftyDayAverage': 481.0074,
#  'twoHundredDayAverage': 483.97256,
#  'trailingAnnualDividendRate': 3.4,
#  'trailingAnnualDividendYield': 0.0072969203,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 3481479413760,
#  'profitMargins': 0.35707,
#  'floatShares': 7421452060,
#  'sharesOutstanding': 7432377655,
#  'sharesShort': 52944379,
#  'sharesShortPriorMonth': 61948927,
#  'sharesShortPreviousMonthDate': 1764288000,
#  'dateShortInterest': 1767139200,
#  'sharesPercentSharesOut': 0.0070999996,
#  'heldPercentInsiders': 0.00066,
#  'heldPercentInstitutions': 0.75758004,
#  'shortRatio': 2.35,
#  'shortPercentOfFloat': 0.0070999996,
#  'impliedSharesOutstanding': 7433166379,
#  'bookValue': 48.84,
#  'priceToBook': 9.630733,
#  'lastFiscalYearEnd': 1751241600,
#  'nextFiscalYearEnd': 1782777600,
#  'mostRecentQuarter': 1759190400,
#  'earningsQuarterlyGrowth': 0.125,
#  'netIncomeToCommon': 104912003072,
#  'trailingEps': 14.07,
#  'forwardEps': 18.70204,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1045526400,
#  'enterpriseToRevenue': 11.849,
#  'enterpriseToEbitda': 20.918,
#  '52WeekChange': 0.072234035,
#  'SandP52WeekChange': 0.15024745,
#  'lastDividendValue': 0.91,
#  'lastDividendDate': 1763596800,
#  'quoteType': 'EQUITY',
#  'currentPrice': 470.365,
#  'targetHighPrice': 730.0,
#  'targetLowPrice': 450.0,
#  'targetMeanPrice': 617.8565,
#  'targetMedianPrice': 630.0,
#  'recommendationMean': 1.24138,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 54,
#  'totalCash': 102012002304,
#  'totalCashPerShare': 13.725,
#  'ebitda': 166436995072,
#  'totalDebt': 120375001088,
#  'quickRatio': 1.254,
#  'currentRatio': 1.401,
#  'totalRevenue': 293812011008,
#  'debtToEquity': 33.154,
#  'revenuePerShare': 39.528,
#  'returnOnAssets': 0.14656,
#  'returnOnEquity': 0.32241002,
#  'grossProfits': 202037002240,
#  'freeCashflow': 53327376384,
#  'operatingCashflow': 147038994432,
#  'earningsGrowth': 0.127,
#  'revenueGrowth': 0.184,
#  'grossMargins': 0.68764,
#  'ebitdaMargins': 0.56646997,
#  'operatingMargins': 0.48873,
#  'financialCurrency': 'USD',
#  'symbol': 'MSFT',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 511108200000,
#  'regularMarketChange': 4.414978,
#  'regularMarketDayRange': '462.0 - 470.81',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 25197300,
#  'fiftyTwoWeekLowChange': 125.57498,
#  'fiftyTwoWeekLowChangePercent': 0.36420715,
#  'fiftyTwoWeekRange': '344.79 - 555.45',
#  'fiftyTwoWeekHighChange': -85.08502,
#  'fiftyTwoWeekHighChangePercent': -0.15318213,
#  'fiftyTwoWeekChangePercent': 7.2234035,
#  'dividendDate': 1773273600,
#  'earningsTimestamp': 1769634000,
#  'earningsTimestampStart': 1769634000,
#  'earningsTimestampEnd': 1769634000,
#  'earningsCallTimestampStart': 1769639400,
#  'earningsCallTimestampEnd': 1769639400,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 14.07,
#  'epsForward': 18.70204,
#  'epsCurrentYear': 16.46054,
#  'priceEpsCurrentYear': 28.575306,
#  'fiftyDayAverageChange': -10.642395,
#  'fiftyDayAverageChangePercent': -0.022125222,
#  'twoHundredDayAverageChange': -13.607574,
#  'twoHundredDayAverageChangePercent': -0.028116416,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '1.2 - Strong Buy',
#  'cryptoTradeable': False,
#  'longName': 'Microsoft Corporation',
#  'shortName': 'Microsoft Corporation',
#  'marketState': 'REGULAR',
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_21835',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': 0.9475218,
#  'regularMarketPrice': 470.365,
#  'corporateActions': [{'header': 'Dividend',
#    'message': 'MSFT announced a cash dividend of 0.91$ with an ex-date of Feb. 19, 2026',
#    'meta': {'eventType': 'DIVIDEND',
#     'dateEpochMs': 1771477200000,
#     'amount': '0.91'}}],
#  'regularMarketTime': 1769443031,
#  'displayName': 'Microsoft',
#  'trailingPegRatio': 1.8864}

# %%
hist = msft.history(period="5d")
display(hist)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-01-20 00:00:00-05:00  451.220001  456.799988  449.279999  454.519989
# 2026-01-21 00:00:00-05:00  452.600006  452.690002  438.679993  444.109985
# 2026-01-22 00:00:00-05:00  447.619995  452.839996  444.700012  451.140015
# 2026-01-23 00:00:00-05:00  451.869995  471.100006  450.529999  465.950012
# 2026-01-26 00:00:00-05:00  465.304993  470.809998  462.000000  470.429993
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026-01-20 00:00:00-05:00  26130000        0.0           0.0
# 2026-01-21 00:00:00-05:00  37980500        0.0           0.0
# 2026-01-22 00:00:00-05:00  25349400        0.0           0.0
# 2026-01-23 00:00:00-05:00  37962400        0.0           0.0
# 2026-01-26 00:00:00-05:00   7794092        0.0           0.0

# %%
msft.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         12   45     1     0           0
# 1    -1m         12   44     1     0           0
# 2    -2m         12   44     1     0           0
# 3    -3m         12   45     0     0           0
