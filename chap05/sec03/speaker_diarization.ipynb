# %% [markdown]
# ## 05-3 문장과 화자 구분하기
# - Whisper API는 화자 구분해주지 않음

# %% [markdown]
# ### 실습. 화자 분리 모델로 시간대별 화자 구분하기
# - pyannote.audio
#     - 화자 분리 기능 제공
#     - 오픈소스 툴킷
#     - PyTorch 머신러닝 프레임워크에서 동작

# %% [markdown]
# Hugging Face에서 화자 분리 모델 내려받고 사용 준비하기
# Requirements 준수
# - Accept pyannote/segmentation-3.0 user conditions
# - Accept pyannote/speaker-diarization-community-1 user conditions
# - Accept pyannote/speaker-diarization-3.1 user conditions
# - Create access token at hf.co/settings/tokens.
# - 가이드문서 갱신이 느림. 반영되지 않아 문제 빈번하게 발생

# %% [markdown]
# #### Pyannote.audio와 numpy 설치하기

# %%
# %pip install pyannote.audio
# %pip install numpy==1.26
# Out:
# 50204.43s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# WARNING: Ignoring invalid distribution ~etuptools (/Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages)
# Requirement already satisfied: pyannote.audio in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (4.0.3)
# Requirement already satisfied: asteroid-filterbanks>=0.4.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (0.4.0)
# Requirement already satisfied: einops>=0.8.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (0.8.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (0.36.0)
# Requirement already satisfied: lightning>=2.4 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (2.6.0)
# Requirement already satisfied: matplotlib>=3.10.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (3.10.8)
# Requirement already satisfied: opentelemetry-api>=1.34.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp>=1.34.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.34.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (1.39.1)
# Requirement already satisfied: pyannote-core>=6.0.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (6.0.1)
# Requirement already satisfied: pyannote-database>=6.1.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (6.1.1)
# Requirement already satisfied: pyannote-metrics>=4.0.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (4.0.0)
# Requirement already satisfied: pyannote-pipeline>=4.0.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (4.0.0)
# Requirement already satisfied: pyannoteai-sdk>=0.3.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (0.4.0)
# Requirement already satisfied: pytorch-metric-learning>=2.8.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (2.9.0)
# Requirement already satisfied: rich>=13.9.4 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (14.2.0)
# Requirement already satisfied: safetensors>=0.5.2 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (0.7.0)
# Requirement already satisfied: soundfile>=0.13.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (0.13.1)
# Requirement already satisfied: torch-audiomentations>=0.12.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (0.12.0)
# Requirement already satisfied: torch==2.8.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (2.8.0)
# Requirement already satisfied: torchaudio==2.8.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (2.8.0)
# Requirement already satisfied: torchcodec==0.7.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (0.7.0)
# Requirement already satisfied: torchmetrics>=1.6.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote.audio) (1.8.2)
# Requirement already satisfied: filelock in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from torch==2.8.0->pyannote.audio) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from torch==2.8.0->pyannote.audio) (4.15.0)
# Requirement already satisfied: setuptools in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from torch==2.8.0->pyannote.audio) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from torch==2.8.0->pyannote.audio) (1.14.0)
# Requirement already satisfied: networkx in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from torch==2.8.0->pyannote.audio) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from torch==2.8.0->pyannote.audio) (3.1.6)
# Requirement already satisfied: fsspec in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from torch==2.8.0->pyannote.audio) (2025.10.0)
# Requirement already satisfied: numpy in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from asteroid-filterbanks>=0.4.0->pyannote.audio) (1.26.0)
# Requirement already satisfied: packaging>=20.9 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from huggingface-hub>=0.28.1->pyannote.audio) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from huggingface-hub>=0.28.1->pyannote.audio) (6.0.3)
# Requirement already satisfied: requests in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from huggingface-hub>=0.28.1->pyannote.audio) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from huggingface-hub>=0.28.1->pyannote.audio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from huggingface-hub>=0.28.1->pyannote.audio) (1.2.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from lightning>=2.4->pyannote.audio) (0.15.2)
# Requirement already satisfied: pytorch-lightning in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from lightning>=2.4->pyannote.audio) (2.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning>=2.4->pyannote.audio) (3.13.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.4->pyannote.audio) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.4->pyannote.audio) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.4->pyannote.audio) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.4->pyannote.audio) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.4->pyannote.audio) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.4->pyannote.audio) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.4->pyannote.audio) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning>=2.4->pyannote.audio) (3.11)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from matplotlib>=3.10.0->pyannote.audio) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from matplotlib>=3.10.0->pyannote.audio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from matplotlib>=3.10.0->pyannote.audio) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from matplotlib>=3.10.0->pyannote.audio) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from matplotlib>=3.10.0->pyannote.audio) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from matplotlib>=3.10.0->pyannote.audio) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from matplotlib>=3.10.0->pyannote.audio) (2.9.0.post0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from opentelemetry-api>=1.34.0->pyannote.audio) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.34.0->pyannote.audio) (3.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.39.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp>=1.34.0->pyannote.audio) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.39.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp>=1.34.0->pyannote.audio) (1.39.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp>=1.34.0->pyannote.audio) (1.72.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp>=1.34.0->pyannote.audio) (1.76.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp>=1.34.0->pyannote.audio) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp>=1.34.0->pyannote.audio) (1.39.1)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from opentelemetry-proto==1.39.1->opentelemetry-exporter-otlp-proto-grpc==1.39.1->opentelemetry-exporter-otlp>=1.34.0->pyannote.audio) (6.33.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from opentelemetry-sdk>=1.34.0->pyannote.audio) (0.60b1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.28.1->pyannote.audio) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.28.1->pyannote.audio) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from requests->huggingface-hub>=0.28.1->pyannote.audio) (2025.11.12)
# Collecting numpy (from asteroid-filterbanks>=0.4.0->pyannote.audio)
#   Using cached numpy-2.4.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: pandas>=2.2.3 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote-core>=6.0.1->pyannote.audio) (2.3.3)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote-core>=6.0.1->pyannote.audio) (2.4.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pandas>=2.2.3->pyannote-core>=6.0.1->pyannote.audio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pandas>=2.2.3->pyannote-core>=6.0.1->pyannote.audio) (2025.3)
# Requirement already satisfied: scikit-learn>=1.6.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote-metrics>=4.0.0->pyannote.audio) (1.8.0)
# Requirement already satisfied: scipy>=1.15.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote-metrics>=4.0.0->pyannote.audio) (1.17.0)
# Requirement already satisfied: optuna>=4.2.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from pyannote-pipeline>=4.0.0->pyannote.audio) (4.7.0)
# Requirement already satisfied: alembic>=1.5.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from optuna>=4.2.0->pyannote-pipeline>=4.0.0->pyannote.audio) (1.18.1)
# Requirement already satisfied: colorlog in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from optuna>=4.2.0->pyannote-pipeline>=4.0.0->pyannote.audio) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from optuna>=4.2.0->pyannote-pipeline>=4.0.0->pyannote.audio) (2.0.45)
# Requirement already satisfied: Mako in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from alembic>=1.5.0->optuna>=4.2.0->pyannote-pipeline>=4.0.0->pyannote.audio) (1.3.10)
# Requirement already satisfied: six>=1.5 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.0->pyannote.audio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from rich>=13.9.4->pyannote.audio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from rich>=13.9.4->pyannote.audio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->pyannote.audio) (0.1.2)
# Requirement already satisfied: joblib>=1.3.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from scikit-learn>=1.6.1->pyannote-metrics>=4.0.0->pyannote.audio) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from scikit-learn>=1.6.1->pyannote-metrics>=4.0.0->pyannote.audio) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from soundfile>=0.13.1->pyannote.audio) (2.0.0)
# Requirement already satisfied: pycparser in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from cffi>=1.0->soundfile>=0.13.1->pyannote.audio) (2.23)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch==2.8.0->pyannote.audio) (1.3.0)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from torch-audiomentations>=0.12.0->pyannote.audio) (0.2.7)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from torch-audiomentations>=0.12.0->pyannote.audio) (1.2.5)
# Requirement already satisfied: primePy>=1.3 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.12.0->pyannote.audio) (1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from jinja2->torch==2.8.0->pyannote.audio) (3.0.3)
# Using cached numpy-2.4.1-cp312-cp312-macosx_14_0_arm64.whl (5.2 MB)
# WARNING: Ignoring invalid distribution ~etuptools (/Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.0
#     Uninstalling numpy-1.26.0:
#       Successfully uninstalled numpy-1.26.0
# WARNING: Ignoring invalid distribution ~etuptools (/Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages)
# Successfully installed numpy-2.4.1
# Note: you may need to restart the kernel to use updated packages.
# 50213.48s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# WARNING: Ignoring invalid distribution ~etuptools (/Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages)
# Collecting numpy==1.26
#   Using cached numpy-1.26.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (53 kB)
# Using cached numpy-1.26.0-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
# WARNING: Ignoring invalid distribution ~etuptools (/Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.1
#     Uninstalling numpy-2.4.1:
#       Successfully uninstalled numpy-2.4.1
# WARNING: Ignoring invalid distribution ~etuptools (/Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyannote-core 6.0.1 requires numpy>=2.0, but you have numpy 1.26.0 which is incompatible.
# pyannote-metrics 4.0.0 requires numpy>=2.2.2, but you have numpy 1.26.0 which is incompatible.
# scipy 1.17.0 requires numpy<2.7,>=1.26.4, but you have numpy 1.26.0 which is incompatible.
# Successfully installed numpy-1.26.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### pyannote.audio 사용하기
# - 모델 상세 페이지인 Usage 영역의 예제 코드 복사
# - 토큰 관련 내용 수정

# %%
import os
from dotenv import load_dotenv

load_dotenv()

HUGGING_FACE_TOKEN = os.getenv("HUGGING_FACE_TOKEN")

# %%
# instantiate the pipeline
from pyannote.audio import Pipeline

pipeline = Pipeline.from_pretrained(
  "pyannote/speaker-diarization-3.1",
  token=HUGGING_FACE_TOKEN
)

# %% [markdown]
# CUDA 지원하는 GPU는 활용하도록 수정(미지원)
# If you’re on macOS and want GPU, CUDA won’t be available; use MPS instead:
# (Metal Performance Shaders)

# %%
import torch

if torch.cuda.is_available():
    print('cuda is available')
else:
    print('cuda is not available')

if torch.backends.mps.is_available():
    pipeline.to(torch.device("mps"))
    print("mps is available")
else:
    print("mps is not available")
# Out:
# cuda is not available
# mps is available

# %% [markdown]
# ### 음성 파일에서 화자 ㅍ분리하기
# - 화자 분리 테스트를 위해 화자가 최소 2명 이상 등장하는 음성 파일을 사용

# %% [markdown]
# #### 화자 분리하고 RTTM 파일로 저장하기
# - RTTM = Rich Transcription Time Marked
#     - RTTM 파일은 주로 음성 처리(Speech Processing), 특히 화자 분리(Speaker Diarization) 결과를 기록하는 텍스트 포맷
#     - “누가, 언제, 얼마나 말했는지”를 시간 단위로 정리해 둔 타임라인 로그라고 생각하면 돼.
# - NameError: name 'AudioDecoder' is not defined 해결
#     - https://discuss.huggingface.co/t/problem-with-pyannote-speaker-diarization-3-1/169415
#     - https://huggingface.co/datasets/John6666/forum2/blob/main/torchcodec_windows_error_1.md

# %%
import torchaudio

# Preload -> bypass TorchCodec
waveform, sr = torchaudio.load("../audio/싼기타_비싼기타.mp3")
out = pipeline({"waveform": waveform, "sample_rate": sr})

ann = out.speaker_diarization
with open("싼기타_비싼기타.rttm", "w", encoding="utf-8") as rttm:
    ann.write_rttm(rttm)
# Out:
# /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(

# %% [markdown]
# ### 판다스를 활용해 데이터프레임 형태로 저장하기
# - 화자 분리는 잘 되지만 한화자의 발언이 여러 행에 나누어 출력되는 문제
# - 같은 화자가 계속 이야기하는 경우에는 하나로 합쳐볼 것
# - Pandas를 이용하면 데이터프레임 형태의 데이터를 쉽게 조작할 수 있음

# %% [markdown]
# #### RTTM을 CSV로 변환하고 데이터프레임으로 출력하기

# %%
import pandas as pd
rttm_path = "./싼기타_비싼기타.rttm"

df_rttm = pd.read_csv(
    rttm_path,  # rttm 파일 경로
    sep=' ',  # 구분자는 띄어쓰기
    header=None,  # 헤더는 없음
    names=['type', 'file', 'chnl', 'start', 'duration', 'C1', 'C2', 'speaker_id', 'C3', 'C4']
)

display(df_rttm)
# Out:
#        type      file  chnl    start  duration  C1  C2  speaker_id  C3  C4
# 0   SPEAKER  waveform     1    0.993     5.805 NaN NaN  SPEAKER_00 NaN NaN
# 1   SPEAKER  waveform     1    7.405     3.983 NaN NaN  SPEAKER_00 NaN NaN
# 2   SPEAKER  waveform     1   11.759     4.927 NaN NaN  SPEAKER_00 NaN NaN
# 3   SPEAKER  waveform     1   17.210    10.665 NaN NaN  SPEAKER_00 NaN NaN
# 4   SPEAKER  waveform     1   28.668     1.536 NaN NaN  SPEAKER_00 NaN NaN
# ..      ...       ...   ...      ...       ...  ..  ..         ...  ..  ..
# 83  SPEAKER  waveform     1  414.481     2.970 NaN NaN  SPEAKER_01 NaN NaN
# 84  SPEAKER  waveform     1  417.755     3.476 NaN NaN  SPEAKER_00 NaN NaN
# 85  SPEAKER  waveform     1  423.644     0.776 NaN NaN  SPEAKER_01 NaN NaN
# 86  SPEAKER  waveform     1  424.741     3.527 NaN NaN  SPEAKER_01 NaN NaN
# 87  SPEAKER  waveform     1  428.504     0.844 NaN NaN  SPEAKER_01 NaN NaN
#
# [88 rows x 10 columns]

# %% [markdown]
# #### 발언 끝난 시간 추가하기

# %%
# start + duration을 end로 변환
df_rttm['end'] = df_rttm['start'] + df_rttm['duration']

display(df_rttm)
# Out:
#        type      file  chnl    start  duration  C1  C2  speaker_id  C3  C4  \
# 0   SPEAKER  waveform     1    0.993     5.805 NaN NaN  SPEAKER_00 NaN NaN
# 1   SPEAKER  waveform     1    7.405     3.983 NaN NaN  SPEAKER_00 NaN NaN
# 2   SPEAKER  waveform     1   11.759     4.927 NaN NaN  SPEAKER_00 NaN NaN
# 3   SPEAKER  waveform     1   17.210    10.665 NaN NaN  SPEAKER_00 NaN NaN
# 4   SPEAKER  waveform     1   28.668     1.536 NaN NaN  SPEAKER_00 NaN NaN
# ..      ...       ...   ...      ...       ...  ..  ..         ...  ..  ..
# 83  SPEAKER  waveform     1  414.481     2.970 NaN NaN  SPEAKER_01 NaN NaN
# 84  SPEAKER  waveform     1  417.755     3.476 NaN NaN  SPEAKER_00 NaN NaN
# 85  SPEAKER  waveform     1  423.644     0.776 NaN NaN  SPEAKER_01 NaN NaN
# 86  SPEAKER  waveform     1  424.741     3.527 NaN NaN  SPEAKER_01 NaN NaN
# 87  SPEAKER  waveform     1  428.504     0.844 NaN NaN  SPEAKER_01 NaN NaN
#
#         end
# 0     6.798
# 1    11.388
# 2    16.686
# 3    27.875
# 4    30.204
# ..      ...
# 83  417.451
# 84  421.231
# 85  424.420
# 86  428.268
# 87  429.348
#
# [88 rows x 11 columns]

# %% [markdown]
# #### 연속된 발화를 기록하기 위해 number 변수 추가하기
# - 화자를 구분하고 발언 순서를 기록하기 위해 화자가 바뀔 때마다 발언에 번호 부여

# %%
df_rttm["number"] = None  # number 열 만들고 None으로 초기화
df_rttm.at[0, "number"] = 0

display(df_rttm)
# Out:
#        type      file  chnl    start  duration  C1  C2  speaker_id  C3  C4  \
# 0   SPEAKER  waveform     1    0.993     5.805 NaN NaN  SPEAKER_00 NaN NaN
# 1   SPEAKER  waveform     1    7.405     3.983 NaN NaN  SPEAKER_00 NaN NaN
# 2   SPEAKER  waveform     1   11.759     4.927 NaN NaN  SPEAKER_00 NaN NaN
# 3   SPEAKER  waveform     1   17.210    10.665 NaN NaN  SPEAKER_00 NaN NaN
# 4   SPEAKER  waveform     1   28.668     1.536 NaN NaN  SPEAKER_00 NaN NaN
# ..      ...       ...   ...      ...       ...  ..  ..         ...  ..  ..
# 83  SPEAKER  waveform     1  414.481     2.970 NaN NaN  SPEAKER_01 NaN NaN
# 84  SPEAKER  waveform     1  417.755     3.476 NaN NaN  SPEAKER_00 NaN NaN
# 85  SPEAKER  waveform     1  423.644     0.776 NaN NaN  SPEAKER_01 NaN NaN
# 86  SPEAKER  waveform     1  424.741     3.527 NaN NaN  SPEAKER_01 NaN NaN
# 87  SPEAKER  waveform     1  428.504     0.844 NaN NaN  SPEAKER_01 NaN NaN
#
#         end number
# 0     6.798      0
# 1    11.388   None
# 2    16.686   None
# 3    27.875   None
# 4    30.204   None
# ..      ...    ...
# 83  417.451   None
# 84  421.231   None
# 85  424.420   None
# 86  428.268   None
# 87  429.348   None
#
# [88 rows x 12 columns]

# %% [markdown]
# #### 화자 번호 매기기
# - 두 번째 행(i = 1)부터 시작해서 이전 행(i - 1)의 speaker_id가 같으면 그 행의 number를 그대로 가져오고
# - 다르면 number에 1을 더해 새로운 번호 붙임

# %%
for i in range(1, len(df_rttm)):
    if df_rttm.at[i, "speaker_id"] != df_rttm.at[i-1, "speaker_id"]:
        df_rttm.at[i, "number"] = df_rttm.at[i-1, "number"] + 1
    else:
        df_rttm.at[i, "number"] = df_rttm.at[i-1, "number"]

display(df_rttm.head(10))
# Out:
#       type      file  chnl   start  duration  C1  C2  speaker_id  C3  C4  \
# 0  SPEAKER  waveform     1   0.993     5.805 NaN NaN  SPEAKER_00 NaN NaN
# 1  SPEAKER  waveform     1   7.405     3.983 NaN NaN  SPEAKER_00 NaN NaN
# 2  SPEAKER  waveform     1  11.759     4.927 NaN NaN  SPEAKER_00 NaN NaN
# 3  SPEAKER  waveform     1  17.210    10.665 NaN NaN  SPEAKER_00 NaN NaN
# 4  SPEAKER  waveform     1  28.668     1.536 NaN NaN  SPEAKER_00 NaN NaN
# 5  SPEAKER  waveform     1  32.414     0.759 NaN NaN  SPEAKER_01 NaN NaN
# 6  SPEAKER  waveform     1  33.545     3.561 NaN NaN  SPEAKER_01 NaN NaN
# 7  SPEAKER  waveform     1  37.628     3.763 NaN NaN  SPEAKER_01 NaN NaN
# 8  SPEAKER  waveform     1  41.611     0.844 NaN NaN  SPEAKER_00 NaN NaN
# 9  SPEAKER  waveform     1  41.645     1.063 NaN NaN  SPEAKER_01 NaN NaN
#
#       end number
# 0   6.798      0
# 1  11.388      0
# 2  16.686      0
# 3  27.875      0
# 4  30.204      0
# 5  33.173      1
# 6  37.106      1
# 7  41.391      1
# 8  42.455      2
# 9  42.708      3

# %% [markdown]
# #### 같은 화자끼리 묶어서 정리하기
# - number가 같은 행들을 하나로 묶고 start는 최솟값, end는 최댓값으로 설정

# %%
df_rttm_grouped = df_rttm.groupby("number").agg(
    start=pd.NamedAgg(column='start', aggfunc='min'),
    end=pd.NamedAgg(column='end', aggfunc='max'),
    speaker_id=pd.NamedAgg(column='speaker_id', aggfunc='first')
)

display(df_rttm_grouped)
# Out:
#           start      end  speaker_id
# number
# 0         0.993   30.204  SPEAKER_00
# 1        32.414   41.391  SPEAKER_01
# 2        41.611   42.455  SPEAKER_00
# 3        41.645   42.708  SPEAKER_01
# 4        42.674   44.024  SPEAKER_00
# 5        45.813   67.109  SPEAKER_01
# 6        67.227   82.786  SPEAKER_00
# 7        84.659  102.564  SPEAKER_01
# 8       103.492  117.532  SPEAKER_00
# 9       119.759  138.676  SPEAKER_01
# 10      139.351  168.967  SPEAKER_00
# 11      170.907  192.321  SPEAKER_01
# 12      192.322  193.689  SPEAKER_00
# 13      192.760  193.503  SPEAKER_01
# 14      193.823  216.571  SPEAKER_00
# 15      218.579  237.783  SPEAKER_01
# 16      238.103  238.677  SPEAKER_00
# 17      238.188  239.352  SPEAKER_01
# 18      239.858  240.651  SPEAKER_00
# 19      240.297  240.989  SPEAKER_01
# 20      240.989  251.334  SPEAKER_00
# 21      253.696  271.550  SPEAKER_01
# 22      272.140  304.557  SPEAKER_00
# 23      306.970  326.022  SPEAKER_01
# 24      326.360  335.472  SPEAKER_00
# 25      337.548  355.925  SPEAKER_01
# 26      356.245  363.974  SPEAKER_00
# 27      365.982  381.423  SPEAKER_01
# 28      382.165  383.734  SPEAKER_00
# 29      385.726  397.184  SPEAKER_01
# 30      397.623  399.108  SPEAKER_00
# 31      401.437  406.601  SPEAKER_01
# 32      407.326  408.338  SPEAKER_00
# 33      410.093  417.451  SPEAKER_01
# 34      417.755  421.231  SPEAKER_00
# 35      423.644  429.348  SPEAKER_01

# %% [markdown]
# #### 발화 시간 추가하고 인덱스 제거하기
# - 최종 결과 출력 시 일반 열로 변경해야 처리하기 쉬우므로 인덱스 삭제

# %%
df_rttm_grouped["duration"] = df_rttm_grouped["end"] - df_rttm_grouped["start"]
df_rttm_grouped = df_rttm_grouped.reset_index(drop=True)
display(df_rttm_grouped)
# Out:
#       start      end  speaker_id  duration
# 0     0.993   30.204  SPEAKER_00    29.211
# 1    32.414   41.391  SPEAKER_01     8.977
# 2    41.611   42.455  SPEAKER_00     0.844
# 3    41.645   42.708  SPEAKER_01     1.063
# 4    42.674   44.024  SPEAKER_00     1.350
# 5    45.813   67.109  SPEAKER_01    21.296
# 6    67.227   82.786  SPEAKER_00    15.559
# 7    84.659  102.564  SPEAKER_01    17.905
# 8   103.492  117.532  SPEAKER_00    14.040
# 9   119.759  138.676  SPEAKER_01    18.917
# 10  139.351  168.967  SPEAKER_00    29.616
# 11  170.907  192.321  SPEAKER_01    21.414
# 12  192.322  193.689  SPEAKER_00     1.367
# 13  192.760  193.503  SPEAKER_01     0.743
# 14  193.823  216.571  SPEAKER_00    22.748
# 15  218.579  237.783  SPEAKER_01    19.204
# 16  238.103  238.677  SPEAKER_00     0.574
# 17  238.188  239.352  SPEAKER_01     1.164
# 18  239.858  240.651  SPEAKER_00     0.793
# 19  240.297  240.989  SPEAKER_01     0.692
# 20  240.989  251.334  SPEAKER_00    10.345
# 21  253.696  271.550  SPEAKER_01    17.854
# 22  272.140  304.557  SPEAKER_00    32.417
# 23  306.970  326.022  SPEAKER_01    19.052
# 24  326.360  335.472  SPEAKER_00     9.112
# 25  337.548  355.925  SPEAKER_01    18.377
# 26  356.245  363.974  SPEAKER_00     7.729
# 27  365.982  381.423  SPEAKER_01    15.441
# 28  382.165  383.734  SPEAKER_00     1.569
# 29  385.726  397.184  SPEAKER_01    11.458
# 30  397.623  399.108  SPEAKER_00     1.485
# 31  401.437  406.601  SPEAKER_01     5.164
# 32  407.326  408.338  SPEAKER_00     1.012
# 33  410.093  417.451  SPEAKER_01     7.358
# 34  417.755  421.231  SPEAKER_00     3.476
# 35  423.644  429.348  SPEAKER_01     5.704

# %% [markdown]
# #### 화자 분리 결과를 CSV 파일로 저장하기

# %%
df_rttm_grouped.to_csv(
    "./싼기타_비싼기타_rttm.csv",
    sep=',',
    index=False
)
