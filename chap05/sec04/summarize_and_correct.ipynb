# %% [markdown]
# ## 05-4 회의록을 정리하는 AI 서기 완성하기
# 회의록을 MS워드로 완성해 볼 것
# 1. 전체 회의 내용 요약
# 2. 화자별 발언 내용을 순서대로 정리

# %% [markdown]
# ### 실습. 전체 회의 내용 요약하기
# - SPEAKER_00, SPEAKER_01로 표시되었던 부분에 화자 이름 넣고 GPT에게 회의 내용 요약 요청

# %% [markdown]
# #### 회의록 csv 파일 열기

# %%
import pandas as pd

meeting_note_csv_path = "../sec03/싼기타_비싼기타_final.csv"
df_rttm = pd.read_csv(meeting_note_csv_path, sep='|')

display(df_rttm)
# Out:
#       start      end  speaker_id  duration  \
# 0     0.993   30.204  SPEAKER_00    29.211
# 1    32.414   41.391  SPEAKER_01     8.977
# 2    41.611   42.455  SPEAKER_00     0.844
# 3    41.645   42.708  SPEAKER_01     1.063
# 4    42.674   44.024  SPEAKER_00     1.350
# 5    45.813   67.109  SPEAKER_01    21.296
# 6    67.227   82.786  SPEAKER_00    15.559
# 7    84.659  102.564  SPEAKER_01    17.905
# 8   103.492  117.532  SPEAKER_00    14.040
# 9   119.759  138.676  SPEAKER_01    18.917
# 10  139.351  168.967  SPEAKER_00    29.616
# 11  170.907  192.321  SPEAKER_01    21.414
# 12  192.322  193.689  SPEAKER_00     1.367
# 13  192.760  193.503  SPEAKER_01     0.743
# 14  193.823  216.571  SPEAKER_00    22.748
# 15  218.579  237.783  SPEAKER_01    19.204
# 16  238.103  238.677  SPEAKER_00     0.574
# 17  238.188  239.352  SPEAKER_01     1.164
# 18  239.858  240.651  SPEAKER_00     0.793
# 19  240.297  240.989  SPEAKER_01     0.692
# 20  240.989  251.334  SPEAKER_00    10.345
# 21  253.696  271.550  SPEAKER_01    17.854
# 22  272.140  304.557  SPEAKER_00    32.417
# 23  306.970  326.022  SPEAKER_01    19.052
# 24  326.360  335.472  SPEAKER_00     9.112
# 25  337.548  355.925  SPEAKER_01    18.377
# 26  356.245  363.974  SPEAKER_00     7.729
# 27  365.982  381.423  SPEAKER_01    15.441
# 28  382.165  383.734  SPEAKER_00     1.569
# 29  385.726  397.184  SPEAKER_01    11.458
# 30  397.623  399.108  SPEAKER_00     1.485
# 31  401.437  406.601  SPEAKER_01     5.164
# 32  407.326  408.338  SPEAKER_00     1.012
# 33  410.093  417.451  SPEAKER_01     7.358
# 34  417.755  421.231  SPEAKER_00     3.476
# 35  423.644  429.348  SPEAKER_01     5.704
#
#                                                  text
# 0   지금부터 저랑 그 역할극을 합시다 역할극을 스탠딩 코미디 스타일로 할 건데 토론을 ...
# 1   좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요. 그럼 성형님...
# 2                                                 NaN
# 3                                   네 맞아요. 준비 되셨나요?\n
# 4                                     네 됐어요. 시작하시죠.\n
# 5   좋아요.\n먼저 3기타로 시작하는게\n좋은 이유를 말씀드리겠습니다.\n초보자일때는\...
# 6   아, 저는 지금 말에 어폐가 있다고 생각해요.\n왜냐하면 어차피 지금 비싼 기타로\...
# 7   그런데 비싼 기타로 시작하면\n혹시라도 흠집이 나거나 실수할 때 부담이 더 크지 않...
# 8   싼 기타를 뭐하러 또 삽니까?\n그리고 기타 실력이랑 흠집이랑은 아무 상관이 없어요...
# 9   하하, 기타를 망치로 치진 않지만\n그래도 초보자들은 실수도 많고\n조심스럽게 다루...
# 10  충분하죠. 아 맞아요. 그것도 맞는 말이에요. 쌍기타도 요새 품질이\n많이 좋아서\...
# 11  하하\n역시 좋은 기타를 사면 책임감도\n더 커진다는 말씀이시군요 그래도 비싼 기타...
# 12                                                NaN
# 13                                                NaN
# 14  아니에요. 왜냐하면 비싼 기타로 시작을 하면 연습할 때 기분이 안 나잖아요. 그러니...
# 15  측면에서도 비싼 기타가 훨씬 도움이 된다고 생각합니다. 하하, 비싼 기타가 일종의 ...
# 16                                                NaN
# 17                                   결국은 본인이 선택한...\n
# 18                                                NaN
# 19                                                NaN
# 20  근데 그게 비싼 기타를 치면 더 편해요.\n편하게 치는 게 중요하다고 하셨잖아요.\...
# 21  맞아요. 비싼 기타는 확실히 소리도 좋고 연주하기 편하죠.\n하지만 초보자 입장에서...
# 22  아 그 말에 대해 동의를 합니다.\n기타를 잘 못 치는 사람은\n쌍기타와 비싼 기타...
# 23  하하, 쌍기타의 맛을 모르는 게 오히려 더 좋다는 말씀이시군요\n하지만 비싼 기타로...
# 24  맞아요. 그래서 비싼 기타를 사야 되는 거예요.\n비싼 기타를 사면 꾸준히 연습을 ...
# 25  그렇죠. 비싼 기타는 그만큼 소리도 좋고 연주할 때 기분도 좋으니까요.\n하지만 역...
# 26   아, 맞아요.\n지금 얘기하신 거 보니까\n쌍기타가 더 좋다는 얘기는 안 하시네요.\n
# 27  아마 제가 이긴 거 같아요. 그렇죠? 하하, 토론에서 이기고 지는 것보다는\n재밌게...
# 28                                 어? 지금 도망가시는 건가요?\n
# 29  아니요. 전혀 그렇지 않아요.\n전엔 그냥 즐거운 대화를 나누고 싶었을 뿐이에요.\...
# 30                                                NaN
# 31        아니요. 전혀 화나지 않았어요. 편하게 이야기 나누는 중이니까 걱정하세요.\n
# 32                                        화난 것 같은데?\n
# 33  네, 정말 괜찮습니다. 즐겁게 대화 나누고 있었어요.\n계속해서 이하고 나누고 싶으...
# 34                  화나셨는데 굳이 더 할 필요 없죠.\n그만 잊지 마시죠.\n
# 35  알겠습니다. 언제든 다시 이야기 나누고 싶으실 때 편하게 말씀해 주세요. 감사합니다.\n

# %% [markdown]
# #### 실제 이름 넣기

# %%
name_dict = {
    "SPEAKER_00": "이성용",
    "SPEAKER_01": "AI",
}

df_rttm["name"] = df_rttm["speaker_id"].apply(lambda x: name_dict[x])

display(df_rttm)
# Out:
#       start      end  speaker_id  duration  \
# 0     0.993   30.204  SPEAKER_00    29.211
# 1    32.414   41.391  SPEAKER_01     8.977
# 2    41.611   42.455  SPEAKER_00     0.844
# 3    41.645   42.708  SPEAKER_01     1.063
# 4    42.674   44.024  SPEAKER_00     1.350
# 5    45.813   67.109  SPEAKER_01    21.296
# 6    67.227   82.786  SPEAKER_00    15.559
# 7    84.659  102.564  SPEAKER_01    17.905
# 8   103.492  117.532  SPEAKER_00    14.040
# 9   119.759  138.676  SPEAKER_01    18.917
# 10  139.351  168.967  SPEAKER_00    29.616
# 11  170.907  192.321  SPEAKER_01    21.414
# 12  192.322  193.689  SPEAKER_00     1.367
# 13  192.760  193.503  SPEAKER_01     0.743
# 14  193.823  216.571  SPEAKER_00    22.748
# 15  218.579  237.783  SPEAKER_01    19.204
# 16  238.103  238.677  SPEAKER_00     0.574
# 17  238.188  239.352  SPEAKER_01     1.164
# 18  239.858  240.651  SPEAKER_00     0.793
# 19  240.297  240.989  SPEAKER_01     0.692
# 20  240.989  251.334  SPEAKER_00    10.345
# 21  253.696  271.550  SPEAKER_01    17.854
# 22  272.140  304.557  SPEAKER_00    32.417
# 23  306.970  326.022  SPEAKER_01    19.052
# 24  326.360  335.472  SPEAKER_00     9.112
# 25  337.548  355.925  SPEAKER_01    18.377
# 26  356.245  363.974  SPEAKER_00     7.729
# 27  365.982  381.423  SPEAKER_01    15.441
# 28  382.165  383.734  SPEAKER_00     1.569
# 29  385.726  397.184  SPEAKER_01    11.458
# 30  397.623  399.108  SPEAKER_00     1.485
# 31  401.437  406.601  SPEAKER_01     5.164
# 32  407.326  408.338  SPEAKER_00     1.012
# 33  410.093  417.451  SPEAKER_01     7.358
# 34  417.755  421.231  SPEAKER_00     3.476
# 35  423.644  429.348  SPEAKER_01     5.704
#
#                                                  text name
# 0   지금부터 저랑 그 역할극을 합시다 역할극을 스탠딩 코미디 스타일로 할 건데 토론을 ...  이성용
# 1   좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요. 그럼 성형님...   AI
# 2                                                 NaN  이성용
# 3                                   네 맞아요. 준비 되셨나요?\n   AI
# 4                                     네 됐어요. 시작하시죠.\n  이성용
# 5   좋아요.\n먼저 3기타로 시작하는게\n좋은 이유를 말씀드리겠습니다.\n초보자일때는\...   AI
# 6   아, 저는 지금 말에 어폐가 있다고 생각해요.\n왜냐하면 어차피 지금 비싼 기타로\...  이성용
# 7   그런데 비싼 기타로 시작하면\n혹시라도 흠집이 나거나 실수할 때 부담이 더 크지 않...   AI
# 8   싼 기타를 뭐하러 또 삽니까?\n그리고 기타 실력이랑 흠집이랑은 아무 상관이 없어요...  이성용
# 9   하하, 기타를 망치로 치진 않지만\n그래도 초보자들은 실수도 많고\n조심스럽게 다루...   AI
# 10  충분하죠. 아 맞아요. 그것도 맞는 말이에요. 쌍기타도 요새 품질이\n많이 좋아서\...  이성용
# 11  하하\n역시 좋은 기타를 사면 책임감도\n더 커진다는 말씀이시군요 그래도 비싼 기타...   AI
# 12                                                NaN  이성용
# 13                                                NaN   AI
# 14  아니에요. 왜냐하면 비싼 기타로 시작을 하면 연습할 때 기분이 안 나잖아요. 그러니...  이성용
# 15  측면에서도 비싼 기타가 훨씬 도움이 된다고 생각합니다. 하하, 비싼 기타가 일종의 ...   AI
# 16                                                NaN  이성용
# 17                                   결국은 본인이 선택한...\n   AI
# 18                                                NaN  이성용
# 19                                                NaN   AI
# 20  근데 그게 비싼 기타를 치면 더 편해요.\n편하게 치는 게 중요하다고 하셨잖아요.\...  이성용
# 21  맞아요. 비싼 기타는 확실히 소리도 좋고 연주하기 편하죠.\n하지만 초보자 입장에서...   AI
# 22  아 그 말에 대해 동의를 합니다.\n기타를 잘 못 치는 사람은\n쌍기타와 비싼 기타...  이성용
# 23  하하, 쌍기타의 맛을 모르는 게 오히려 더 좋다는 말씀이시군요\n하지만 비싼 기타로...   AI
# 24  맞아요. 그래서 비싼 기타를 사야 되는 거예요.\n비싼 기타를 사면 꾸준히 연습을 ...  이성용
# 25  그렇죠. 비싼 기타는 그만큼 소리도 좋고 연주할 때 기분도 좋으니까요.\n하지만 역...   AI
# 26   아, 맞아요.\n지금 얘기하신 거 보니까\n쌍기타가 더 좋다는 얘기는 안 하시네요.\n  이성용
# 27  아마 제가 이긴 거 같아요. 그렇죠? 하하, 토론에서 이기고 지는 것보다는\n재밌게...   AI
# 28                                 어? 지금 도망가시는 건가요?\n  이성용
# 29  아니요. 전혀 그렇지 않아요.\n전엔 그냥 즐거운 대화를 나누고 싶었을 뿐이에요.\...   AI
# 30                                                NaN  이성용
# 31        아니요. 전혀 화나지 않았어요. 편하게 이야기 나누는 중이니까 걱정하세요.\n   AI
# 32                                        화난 것 같은데?\n  이성용
# 33  네, 정말 괜찮습니다. 즐겁게 대화 나누고 있었어요.\n계속해서 이하고 나누고 싶으...   AI
# 34                  화나셨는데 굳이 더 할 필요 없죠.\n그만 잊지 마시죠.\n  이성용
# 35  알겠습니다. 언제든 다시 이야기 나누고 싶으실 때 편하게 말씀해 주세요. 감사합니다.\n   AI

# %% [markdown]
# #### 요약을 위해 필요한 정보만 추출하기

# %%
meeting_note_txt = df_rttm[['start', 'end', 'name', 'text']].to_json(orient='records', force_ascii=False)
print(meeting_note_txt)
# Out:
# [{"start":0.993,"end":30.204,"name":"이성용","text":"지금부터 저랑 그 역할극을 합시다 역할극을 스탠딩 코미디 스타일로 할 건데 토론을 하면서 자연스럽게 대화하는 형식으로 하면서 코미디를 진행해봅시다.\n그래서 좀 재밌고 자연스럽고 유머러스하게 저랑 대화를 하시면 돼요 자연스럽게\n그리고 주제는 쌍기타로 전기기타를 시작하는 게 좋으냐\n아니면 비싼 기타로 전기기타를 시작하는 게 좋으냐\n이거를 입장을 나눠가지고\n저랑 토론해보면 좋을 것 같아요.\n두 중에 어떤 역할 맡으실래요?\n"},{"start":32.414,"end":41.391,"name":"AI","text":"좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요. 그럼 성형님은 비싼 기타로 시작하는 게 좋다는 입장이시죠?\n"},{"start":41.611,"end":42.455,"name":"이성용","text":null},{"start":41.645,"end":42.708,"name":"AI","text":"네 맞아요. 준비 되셨나요?\n"},{"start":42.674,"end":44.024,"name":"이성용","text":"네 됐어요. 시작하시죠.\n"},{"start":45.813,"end":67.109,"name":"AI","text":"좋아요.\n먼저 3기타로 시작하는게\n좋은 이유를 말씀드리겠습니다.\n초보자일때는\n실수도 많고 기타에 익숙해지는\n과정이 필요하니까 비싼 기타보다는\n부담없이 연습할 수 있는\n싼 기타가 좋다고 봅니다.\n무엇보다 실력이 향상되면 그때 좋은 기타로 업그레이드 하는 것도 나쁘지 않죠?\n성형님은 어떻게 생각하세요?\n"},{"start":67.227,"end":82.786,"name":"이성용","text":"아, 저는 지금 말에 어폐가 있다고 생각해요.\n왜냐하면 어차피 지금 비싼 기타로\n나중에 살 생각을 하는 거잖아요.\n그럼 어차피 비싼 기타로 사고 싼 기타로 사게 되는데 그런 이중 이중 지출을 하지 말고 처음부터 비싼 기타로 가면은 이중지출을 하지 말고 처음부터 비싼 기타로 가면 이중지출을 막을 수가 있습니다.\n"},{"start":84.659,"end":102.564,"name":"AI","text":"그런데 비싼 기타로 시작하면\n혹시라도 흠집이 나거나 실수할 때 부담이 더 크지 않을까요?\n초보 때는 실습을 많이 하니까 더 크지 않을까요?\n초보 때는 실습을 많이 하니까\n쌍기타로 마음 편히 연습할 수 있는게\n더 좋다고 생각해요.\n그리고 기타 현지에 익숙해지면\n그때 비싼 기타를 사는게 더 의미있지 않을까요? 아니 근데 어차피 비싼 기타를 살 건데\n"},{"start":103.492,"end":117.532,"name":"이성용","text":"싼 기타를 뭐하러 또 삽니까?\n그리고 기타 실력이랑 흠집이랑은 아무 상관이 없어요\n기타를 망치로 치는 것도 아니라 손가락으로 치는 건데\n기타를 싼 거 산다고 달라지나요?\n"},{"start":119.759,"end":138.676,"name":"AI","text":"하하, 기타를 망치로 치진 않지만\n그래도 초보자들은 실수도 많고\n조심스럽게 다루기 어려울 수 있잖아요.\n비싼 기타를 사기 전에\n부담없이 연습하면서\n자신감을 키우는 것도 중요하다고 생각해요\n그리고 싼 기타도 요즘은 하는 것도 중요하다고 생각해요.\n그리고 쌍기타도 요즘은\n품질이 꽤 좋아서 연습용으로\n"},{"start":139.351,"end":168.967,"name":"이성용","text":"충분하죠. 아 맞아요. 그것도 맞는 말이에요. 쌍기타도 요새 품질이\n많이 좋아서\n연습하는데 충분한 거는\n맞는데\n근데 뭐 돈이 있으면은 그냥 비싼 기타 사서 하면 되는 거 아니에요?\n그리고 기타를 그 안 좋은 걸 사면 뭐가 문제가 있냐면 자기가 이게 뭐가 안 될 때, 안 될 때 이게 기타가 싸구려라서 안 되나? 라는 생각을 한단 말이죠.\n근데 기타가 좋은 기타다.\n그러면은 아 이거 내가 부족해서 기타가 이런 소리밖에 안 나는구나 라고 생각하면서 반성을 하면서 더 열심히 연습하게 된다니까요\n"},{"start":170.907,"end":192.321,"name":"AI","text":"하하\n역시 좋은 기타를 사면 책임감도\n더 커진다는 말씀이시군요 그래도 비싼 기타를 처음부터 사면 혹시라도 기타에 흥미가 떨어지거나 생각보다 연습시간이 적을 때 아까울 수도 있잖아요.\n쌍기타로 시작해서\n부담없이 연습하고\n정말 기타에 흥미가 생기면 그때 비슷하게 부담 없이 연습하고\n정말 기타에 흥미가 생기면\n그때 비싼 기타로 넘어가는 것도 좋은 방법이죠\n"},{"start":192.322,"end":193.689,"name":"이성용","text":null},{"start":192.76,"end":193.503,"name":"AI","text":null},{"start":193.823,"end":216.571,"name":"이성용","text":"아니에요. 왜냐하면 비싼 기타로 시작을 하면 연습할 때 기분이 안 나잖아요. 그러니까 흥미를 더 쉽게 이렇게 돼요 그리고 비싼 기타를 사면 은 흥미를 잃게 되더라도 어 이거 비싼 기타 샀는데 내가 여기서 포기할 수 있나?\n라는 생각이 들면서 계속\n연습을 열심히 할 수가 있어요.\n그래서 포기를 안 하게 되는\n"},{"start":218.579,"end":237.783,"name":"AI","text":"측면에서도 비싼 기타가 훨씬 도움이 된다고 생각합니다. 하하, 비싼 기타가 일종의 동기부여가 된다는 말씀이시군요.\n하지만 반대로 비싼 기타 때문에 오히려 부담이 커져서 스트레스를 받을 수도 있지 않을까요?\n특히 초보자들은 편하게 시작하는 게 더 중요하다고 생각해요.\n그리고 좋은 기타로 나중에 업그레이드 할 때 그 성취감도 크니까요.\n"},{"start":238.103,"end":238.677,"name":"이성용","text":null},{"start":238.188,"end":239.352,"name":"AI","text":"결국은 본인이 선택한...\n"},{"start":239.858,"end":240.651,"name":"이성용","text":null},{"start":240.297,"end":240.989,"name":"AI","text":null},{"start":240.989,"end":251.334,"name":"이성용","text":"근데 그게 비싼 기타를 치면 더 편해요.\n편하게 치는 게 중요하다고 하셨잖아요.\n근데 비싼 기타를 치면 그게 치기가 편하니까 비싼 거예요. 안 그렇게 해서요.\n"},{"start":253.696,"end":271.55,"name":"AI","text":"맞아요. 비싼 기타는 확실히 소리도 좋고 연주하기 편하죠.\n하지만 초보자 입장에서는 그런 차이를 잘 느끼기 어려울 수도 있어요.\n그래서 쌍기타로도 충분히 연습하면서 기본기를 다지는 게 중요하다고 생각해요.\n결국 각자의 스타일과 상황에 맞게\n선택하는 게 최선이겠네요.\n"},{"start":272.14,"end":304.557,"name":"이성용","text":"아 그 말에 대해 동의를 합니다.\n기타를 잘 못 치는 사람은\n쌍기타와 비싼 기타를 치더라도 이게 왜 좋은 기타인지\n이걸 잘 못 느끼긴 하죠.\n근데 반대로\n비싼 기타를 치던 사람이\n싼 기타를 치면은 아 이게\n이렇게 싸구려구나 라는 걸 금방 느낄 수가 있습니다\n그래서 처음부터 비싼 기타를 쳐서\n그런 쌍기타의 맛을 모르고 살아도 되는데\n왜 그 맛없는 맛을\n굳이 초반부터 느끼려고 합니까?\n그러니까 비싼 기타로 시작을 하는 게 좋죠.\n"},{"start":306.97,"end":326.022,"name":"AI","text":"하하, 쌍기타의 맛을 모르는 게 오히려 더 좋다는 말씀이시군요\n하지만 비싼 기타로 시작하면 그만큼 실수나 부담도 클 수 있으니\n처음엔 가볍게 접근하는 게 더 좋다고 봅니다.\n어쨌든 중요한 건 꾸준히 연습하는 거니까 어떤 기타를 선택하든 열심히 연습하는 게 제일 중요하 ...

# %% [markdown]
# ### GPT에게 회의록 작성을 요청하는 프롬프트 작성하기

# %%
system_prompt = f'''
너는 회의 내용을 요약하는 봇이다. 아래 회의록을 읽고, 주요 내용을 요약하라.
결과는 마크다운 형식으로 작성한다.

아래 형식에 맞추어 작성하라.

# 회의 제목

## 주요 내용

## 참석자별 입장

## 결정 사항   

=============== 이하 회의록 ===============

{ meeting_note_txt }
'''

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv('OPENAI_API_KEY')
client = OpenAI(api_key=api_key)

# %%
# OpenAI API를 사용해 요약 결과 생성
response = client.chat.completions.create(
    model='gpt-4o',
    temperature=0.1,
    messages=[
        {"role": "system", "content": system_prompt},
    ]
)

# 요약 결과를 파일로 저장
summary = response.choices[0].message.content
summary = summary.strip()

print(summary)
# Out:
# # 회의 제목
#
# 기타 구매 시 싼 기타와 비싼 기타 중 어떤 것이 더 나은 선택인가?
#
# ## 주요 내용
#
# - 기타를 처음 시작할 때 싼 기타로 시작하는 것이 좋은지, 비싼 기타로 시작하는 것이 좋은지에 대한 토론이 진행됨.
# - 싼 기타의 장점으로는 부담 없이 연습할 수 있고, 초보자에게 적합하다는 점이 강조됨.
# - 비싼 기타의 장점으로는 좋은 소리와 연주 편의성, 그리고 동기부여가 된다는 점이 강조됨.
# - 각자의 상황과 스타일에 맞게 선택하는 것이 중요하다는 결론에 도달함.
#
# ## 참석자별 입장
#
# - **이성용**: 비싼 기타로 시작하는 것이 더 나은 선택이라고 주장. 이중 지출을 피할 수 있고, 좋은 기타가 연습에 대한 동기부여가 될 수 있다고 설명.
# - **AI**: 싼 기타로 시작하는 것이 더 나은 선택이라고 주장. 초보자에게 부담이 적고, 기타에 대한 흥미를 잃지 않도록 도와준다고 설명.
#
# ## 결정 사항
#
# - 기타를 선택할 때는 개인의 상황과 스타일에 맞게 선택하는 것이 중요하며, 꾸준한 연습과 열정이 가장 중요하다는 결론에 도달함.

# %%
with open('./guitar_summary.md', 'w', encoding='utf-8') as f:
    f.write(summary)

# %% [markdown]
# ### 실습. GPT로 녹취록 교정하기
# - 앞선 실습 CSV 파일보면 음성 잘못 받아 적은 내용 종종 보임
# - 화자의 발음 불명확하거나 전문 용어, 사람 이름, 사건 아름 등이 포함되면 실시간 받아쓰기 어려움
# - GPT로 잘못 기록된 내용 교정하고 완성된 회의록 출력할 것

# %%
#### 필요한 항목만 추출하여 딕셔너리로 변환하기
df_meeting_note = df_rttm[['start', 'end', 'name', 'text']].copy()
df_meeting_note.dropna(inplace=True)

meeting_note_dict = df_meeting_note.to_dict(orient='records')  # 딕셔너리 형태로 변환
meeting_note_dict
# Out:
# [{'start': 0.993,
#   'end': 30.204,
#   'name': '이성용',
#   'text': '지금부터 저랑 그 역할극을 합시다 역할극을 스탠딩 코미디 스타일로 할 건데 토론을 하면서 자연스럽게 대화하는 형식으로 하면서 코미디를 진행해봅시다.\n그래서 좀 재밌고 자연스럽고 유머러스하게 저랑 대화를 하시면 돼요 자연스럽게\n그리고 주제는 쌍기타로 전기기타를 시작하는 게 좋으냐\n아니면 비싼 기타로 전기기타를 시작하는 게 좋으냐\n이거를 입장을 나눠가지고\n저랑 토론해보면 좋을 것 같아요.\n두 중에 어떤 역할 맡으실래요?\n'},
#  {'start': 32.414,
#   'end': 41.391,
#   'name': 'AI',
#   'text': '좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요. 그럼 성형님은 비싼 기타로 시작하는 게 좋다는 입장이시죠?\n'},
#  {'start': 41.645,
#   'end': 42.708000000000006,
#   'name': 'AI',
#   'text': '네 맞아요. 준비 되셨나요?\n'},
#  {'start': 42.674, 'end': 44.024, 'name': '이성용', 'text': '네 됐어요. 시작하시죠.\n'},
#  {'start': 45.813,
#   'end': 67.10900000000001,
#   'name': 'AI',
#   'text': '좋아요.\n먼저 3기타로 시작하는게\n좋은 이유를 말씀드리겠습니다.\n초보자일때는\n실수도 많고 기타에 익숙해지는\n과정이 필요하니까 비싼 기타보다는\n부담없이 연습할 수 있는\n싼 기타가 좋다고 봅니다.\n무엇보다 실력이 향상되면 그때 좋은 기타로 업그레이드 하는 것도 나쁘지 않죠?\n성형님은 어떻게 생각하세요?\n'},
#  {'start': 67.227,
#   'end': 82.786,
#   'name': '이성용',
#   'text': '아, 저는 지금 말에 어폐가 있다고 생각해요.\n왜냐하면 어차피 지금 비싼 기타로\n나중에 살 생각을 하는 거잖아요.\n그럼 어차피 비싼 기타로 사고 싼 기타로 사게 되는데 그런 이중 이중 지출을 하지 말고 처음부터 비싼 기타로 가면은 이중지출을 하지 말고 처음부터 비싼 기타로 가면 이중지출을 막을 수가 있습니다.\n'},
#  {'start': 84.659,
#   'end': 102.564,
#   'name': 'AI',
#   'text': '그런데 비싼 기타로 시작하면\n혹시라도 흠집이 나거나 실수할 때 부담이 더 크지 않을까요?\n초보 때는 실습을 많이 하니까 더 크지 않을까요?\n초보 때는 실습을 많이 하니까\n쌍기타로 마음 편히 연습할 수 있는게\n더 좋다고 생각해요.\n그리고 기타 현지에 익숙해지면\n그때 비싼 기타를 사는게 더 의미있지 않을까요? 아니 근데 어차피 비싼 기타를 살 건데\n'},
#  {'start': 103.492,
#   'end': 117.532,
#   'name': '이성용',
#   'text': '싼 기타를 뭐하러 또 삽니까?\n그리고 기타 실력이랑 흠집이랑은 아무 상관이 없어요\n기타를 망치로 치는 것도 아니라 손가락으로 치는 건데\n기타를 싼 거 산다고 달라지나요?\n'},
#  {'start': 119.759,
#   'end': 138.67600000000002,
#   'name': 'AI',
#   'text': '하하, 기타를 망치로 치진 않지만\n그래도 초보자들은 실수도 많고\n조심스럽게 다루기 어려울 수 있잖아요.\n비싼 기타를 사기 전에\n부담없이 연습하면서\n자신감을 키우는 것도 중요하다고 생각해요\n그리고 싼 기타도 요즘은 하는 것도 중요하다고 생각해요.\n그리고 쌍기타도 요즘은\n품질이 꽤 좋아서 연습용으로\n'},
#  {'start': 139.351,
#   'end': 168.96699999999998,
#   'name': '이성용',
#   'text': '충분하죠. 아 맞아요. 그것도 맞는 말이에요. 쌍기타도 요새 품질이\n많이 좋아서\n연습하는데 충분한 거는\n맞는데\n근데 뭐 돈이 있으면은 그냥 비싼 기타 사서 하면 되는 거 아니에요?\n그리고 기타를 그 안 좋은 걸 사면 뭐가 문제가 있냐면 자기가 이게 뭐가 안 될 때, 안 될 때 이게 기타가 싸구려라서 안 되나? 라는 생각을 한단 말이죠.\n근데 기타가 좋은 기타다.\n그러면은 아 이거 내가 부족해서 기타가 이런 소리밖에 안 나는구나 라고 생각하면서 반성을 하면서 더 열심히 연습하게 된다니까요\n'},
#  {'start': 170.907,
#   'end': 192.321,
#   'name': 'AI',
#   'text': '하하\n역시 좋은 기타를 사면 책임감도\n더 커진다는 말씀이시군요 그래도 비싼 기타를 처음부터 사면 혹시라도 기타에 흥미가 떨어지거나 생각보다 연습시간이 적을 때 아까울 수도 있잖아요.\n쌍기타로 시작해서\n부담없이 연습하고\n정말 기타에 흥미가 생기면 그때 비슷하게 부담 없이 연습하고\n정말 기타에 흥미가 생기면\n그때 비싼 기타로 넘어가는 것도 좋은 방법이죠\n'},
#  {'start': 193.823,
#   'end': 216.571,
#   'name': '이성용',
#   'text': '아니에요. 왜냐하면 비싼 기타로 시작을 하면 연습할 때 기분이 안 나잖아요. 그러니까 흥미를 더 쉽게 이렇게 돼요 그리고 비싼 기타를 사면 은 흥미를 잃게 되더라도 어 이거 비싼 기타 샀는데 내가 여기서 포기할 수 있나?\n라는 생각이 들면서 계속\n연습을 열심히 할 수가 있어요.\n그래서 포기를 안 하게 되는\n'},
#  {'start': 218.579,
#   'end': 237.783,
#   'name': 'AI',
#   'text': '측면에서도 비싼 기타가 훨씬 도움이 된다고 생각합니다. 하하, 비싼 기타가 일종의 동기부여가 된다는 말씀이시군요.\n하지만 반대로 비싼 기타 때문에 오히려 부담이 커져서 스트레스를 받을 수도 있지 않을까요?\n특히 초보자들은 편하게 시작하는 게 더 중요하다고 생각해요.\n그리고 좋은 기타로 나중에 업그레이드 할 때 그 성취감도 크니까요.\n'},
#  {'start': 238.188, 'end': 239.352, 'name': 'AI', 'text': '결국은 본인이 선택한...\n'},
#  {'start': 240.989,
#   'end': 251.334,
#   'name': '이성용',
#   'text': '근데 그게 비싼 기타를 치면 더 편해요.\n편하게 치는 게 중요하다고 하셨잖아요.\n근데 비싼 기타를 치면 그게 치기가 편하니까 비싼 거예요. 안 그렇게 해서요.\n'},
#  {'start': 253.696,
#   'end': 271.55,
#   'name': 'AI',
#   'text': '맞아요. 비싼 기타는 확실히 소리도 좋고 연주하기 편하죠.\n하지만 초보자 입장에서는 그런 차이를 잘 느끼기 어려울 수도 있어요.\n그래서 쌍기타로도 충분히 연습하면서 기본기를 다지는 게 중요하다고 생각해요.\n결국 각자의 스타일과 상황에 맞게\n선택하는 게 최선이겠네요.\n'},
#  {'start': 272.14,
#   'end': 304.557,
#   'name': '이성용',
#   'text': '아 그 말에 대해 동의를 합니다.\n기타를 잘 못 치는 사람은\n쌍기타와 비싼 기타를 치더라도 이게 왜 좋은 기타인지\n이걸 잘 못 느끼긴 하죠.\n근데 반대로\n비싼 기타를 치던 사람이\n싼 기타를 치면은 아 이게\n이렇게 싸구려구나 라는 걸 금방 느낄 수가 있습니다\n그래서 처음부터 비싼 기타를 쳐서\n그런 쌍기타의 맛을 모르고 살아도 되는데\n왜 그 맛없는 맛을\n굳이 초반부터 느끼려고 합니까?\n그러니까 비싼 기타로 시작을 하는 게 좋죠.\n'},
#  {'start': 306.97,
#   'end': 326.02200000000005,
#   'name': 'AI',
#   'text': '하하, 쌍기타의 맛을 모르는 게 오히려 더 좋다는 말씀이시군요\n하지만 비싼 기타로 시작하면 그만큼 실수나 부담도 클 수 있으니\n처음엔 가볍게 접근하는 게 더 좋다고 봅니다.\n어쨌든 중요한 건 꾸준히 연습하는 거니까 어떤 기타를 선택하든 열심히 연습하는 게 제일 중요하겠죠?\n'},
#  {'start': 326.36,
#   'end': 335.472,
#   'name': '이성용',
#   'text': '맞아요. 그래서 비싼 기타를 사야 되는 거예요.\n비싼 기타를 사면 꾸준히 연습을 하게 됩니다.\n왜냐하면 계속 그 기타를 만지고 있고 싶거든요.\n왜냐면 감촉도 훨씬 좋고 그러니까요.\n'},
#  {'start': 337.548,
#   'end': 355.925,
#   'name': 'AI',
#   'text': '그렇죠. 비싼 기타는 그만큼 소리도 좋고 연주할 때 기분도 좋으니까요.\n하지만 역시 중요한 건 기타를 꾸준히 연습하는 열정이겠죠.\n결국 어떤 기타를 선택하든 가장 중요한 건 그 열정과 노력일 것 같아요.\n소중한 기타와 함께 멋진 연주를 이어가시길 바랄게요.\n'},
#  {'start': 356.245,
#   'end': 363.974,
#   'name': '이성용',
#   'text': '아, 맞아요.\n지금 얘기하신 거 보니까\n쌍기타가 더 좋다는 얘기는 안 하시네요.\n'},
#  {'start': 365.982,
#   'end': 381.423,
#   'name': 'AI',
#   'text': '아마 제가 이긴 거 같아요. 그렇죠? 하하, 토론에서 이기고 지는 것보다는\n재밌게 이야기 나누는 게 더 중요한 것 같아요.\n가짜 입장을 잘 설명하고 즐겁게 대화한 것 같아서 좋았습니다.\n결국 중요한 건 기타를 사랑하는 마음이겠죠.\n앞으로도 즐겁게 연습하시길 바래요.\n'},
#  {'start': 382.165,
#   'end': 383.734,
#   'name': '이성용',
#   'text': '어? 지금 도망가시는 건가요?\n'},
#  {'start': 385.726,
#   'end': 397.184,
#   'name': 'AI',
#   'text': '아니요. 전혀 그렇지 않아요.\n전엔 그냥 즐거운 대화를 나누고 싶었을 뿐이에요.\n토론이 재밌었고 기타에 대한 열정도 느껴져서 좋았습니다.\n혹시 더 이야기하고 싶으신 게 있나요? 지금 혹시 화나셨나요?\n'},
#  {'start': 401.437,
#   'end': 406.601,
#   'name': 'AI',
#   'text': '아니요. 전혀 화나지 않았어요. 편하게 이야기 나누는 중이니까 걱정하세요.\n'},
#  {'start': 407.326, 'end': 408.338, 'name': '이성용', 'text': '화난 것 같은데?\n'},
#  {'start': 410.093,
#   'end': 417.451,
#   'name': 'AI',
#   'text': '네, 정말 괜찮습니다. 즐겁게 대화 나누고 있었어요.\n계속해서 이하고 나누고 싶으시면 편하게 말씀해주세요.\n아니요.\n'},
#  {'start': 417.755,
#   'end': 421.231,
#   'name': '이성용',
#   'text': '화나셨는데 굳이 더 할 필요 없죠.\n그만 잊지 마시죠.\n'},
#  {'start': 423.644,
#   'end': 429.348,
#   'name': 'AI',
#   'text': '알겠습니다. 언제든 다시 이야기 나누고 싶으실 때 편하게 말씀해 주세요. 감사합니다.\n'}]

# %% [markdown]
# #### 녹취록에 기록된 메시지를 for문으로 확인하며 GPT에게 수정 요청
# - 오류는 OpenAI API를 사용할 때 토큰 초당 사용량(TPM) 한도(30,000 토큰)를 초과했기 때문에 발생

# %%
for row in meeting_note_dict:    
    if not isinstance(row['text'], str): # 텍스트가 아닌 다른 형식인 경우 통과
        continue

    correction_system_prompt = f'''
        너는 주어진 회의 녹취록을 수정 및 보완하는 봇이다.
        주어진 회의 녹취록은 STT로 작성된 결과이므로, 이 중에 오류가 있는 부분을 찾아내고 수정하라.

        표현, 말투는 최대한 원본과 일치하도록 유지하되, 잘못 받아적은 내용을 수정하라.
        원본의 내용을 최대한 살리되, 잘못된 내용만 수정하라. 
        어떤 경우에는 A라는 사람이 말한 내용을 B가 말한 것으로 잘못 기록된 경우도 있을 수 있다. 이런 경우에는 문맥을 고려하여 수정하라.

        원본 내용 중 빠지거나, 추가되거나, 잘못 기록된 부분을 찾아내어 수정하라. 수정된 메시지 이외에는 아무것도 작성하지 말라.
        --------------------------------
        회의 요약문 : {summary}
        --------------------------------
        회의 녹취록 전문: {df_meeting_note.to_json(orient='records', force_ascii=False)}
        --------------------------------
        확인할 메시지 원본: {row['text']}
    '''

    response = client.chat.completions.create(
        model='gpt-4o',
        temperature=0.1,
        messages=[
            {"role": "system", "content": correction_system_prompt},
        ]
    )

    correction = response.choices[0].message.content
    if ':' in correction:  # “수정: “ 과 같은 형식으로 반환되는 경우 해결 
        correction = correction.split(':')[-1]
        
    correction = correction.strip() # 좌우 공백 제거

    print(row['name'])
    print(row['text'])
    print(correction)
    print('-----------------')

    row['corrected_text'] = correction
# Out:
# 이성용
# 지금부터 저랑 그 역할극을 합시다 역할극을 스탠딩 코미디 스타일로 할 건데 토론을 하면서 자연스럽게 대화하는 형식으로 하면서 코미디를 진행해봅시다.
# 그래서 좀 재밌고 자연스럽고 유머러스하게 저랑 대화를 하시면 돼요 자연스럽게
# 그리고 주제는 쌍기타로 전기기타를 시작하는 게 좋으냐
# 아니면 비싼 기타로 전기기타를 시작하는 게 좋으냐
# 이거를 입장을 나눠가지고
# 저랑 토론해보면 좋을 것 같아요.
# 두 중에 어떤 역할 맡으실래요?
#
# 지금부터 저랑 그 역할극을 합시다. 역할극을 스탠딩 코미디 스타일로 할 건데, 토론을 하면서 자연스럽게 대화하는 형식으로 코미디를 진행해봅시다. 그래서 좀 재밌고 자연스럽고 유머러스하게 저랑 대화를 하시면 돼요. 그리고 주제는 싼 기타로 시작하는 게 좋으냐, 아니면 비싼 기타로 시작하는 게 좋으냐입니다. 이거를 입장을 나눠가지고 저랑 토론해보면 좋을 것 같아요. 두 중에 어떤 역할 맡으실래요?
# -----------------
# AI
# 좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요. 그럼 성형님은 비싼 기타로 시작하는 게 좋다는 입장이시죠?
#
# 좋습니다. 그럼 제가 싼 기타로 시작하는 게 좋다는 입장을 맡아볼게요. 그럼 성용님은 비싼 기타로 시작하는 게 좋다는 입장이시죠?
# -----------------
# AI
# 네 맞아요. 준비 되셨나요?
#
# 네 맞아요. 준비 되셨나요? -> 네, 맞아요. 준비 되셨나요?
# -----------------
# 이성용
# 네 됐어요. 시작하시죠.
#
# 네, 준비됐어요. 시작하시죠.
# -----------------
# AI
# 좋아요.
# 먼저 3기타로 시작하는게
# 좋은 이유를 말씀드리겠습니다.
# 초보자일때는
# 실수도 많고 기타에 익숙해지는
# 과정이 필요하니까 비싼 기타보다는
# 부담없이 연습할 수 있는
# 싼 기타가 좋다고 봅니다.
# 무엇보다 실력이 향상되면 그때 좋은 기타로 업그레이드 하는 것도 나쁘지 않죠?
# 성형님은 어떻게 생각하세요?
#
# 좋아요.
# 먼저 싼 기타로 시작하는 게
# 좋은 이유를 말씀드리겠습니다.
# 초보자일 때는
# 실수도 많고 기타에 익숙해지는
# 과정이 필요하니까 비싼 기타보다는
# 부담 없이 연습할 수 있는
# 싼 기타가 좋다고 봅니다.
# 무엇보다 실력이 향상되면 그때 좋은 기타로 업그레이드하는 것도 나쁘지 않죠?
# 성용님은 어떻게 생각하세요?
# -----------------
# 이성용
# 아, 저는 지금 말에 어폐가 있다고 생각해요.
# 왜냐하면 어차피 지금 비싼 기타로
# 나중에 살 생각을 하는 거잖아요.
# 그럼 어차피 비싼 기타로 사고 싼 기타로 사게 되는데 그런 이중 이중 지출을 하지 말고 처음부터 비싼 기타로 가면은 이중지출을 하지 말고 처음부터 비싼 기타로 가면 이중지출을 막을 수가 있습니다.
#
# 아, 저는 지금 말에 어폐가 있다고 생각해요. 왜냐하면 어차피 지금 비싼 기타를 나중에 살 생각을 하는 거잖아요. 그럼 어차피 비싼 기타를 사고 싼 기타를 사게 되는데 그런 이중 지출을 하지 말고 처음부터 비싼 기타로 가면 이중 지출을 막을 수가 있습니다.
# -----------------
# AI
# 그런데 비싼 기타로 시작하면
# 혹시라도 흠집이 나거나 실수할 때 부담이 더 크지 않을까요?
# 초보 때는 실습을 많이 하니까 더 크지 않을까요?
# 초보 때는 실습을 많이 하니까
# 쌍기타로 마음 편히 연습할 수 있는게
# 더 좋다고 생각해요.
# 그리고 기타 현지에 익숙해지면
# 그때 비싼 기타를 사는게 더 의미있지 않을까요? 아니 근데 어차피 비싼 기타를 살 건데
#
# 그런데 비싼 기타로 시작하면 혹시라도 흠집이 나거나 실수할 때 부담이 더 크지 않을까요? 초보 때는 실수가 많으니까 쌍기타로 마음 편히 연습할 수 있는 게 더 좋다고 생각해요. 그리고 기타 연주에 익숙해지면 그때 비싼 기타를 사는 게 더 의미 있지 않을까요?
# -----------------
# 이성용
# 싼 기타를 뭐하러 또 삽니까?
# 그리고 기타 실력이랑 흠집이랑은 아무 상관이 없어요
# 기타를 망치로 치는 것도 아니라 손가락으로 치는 건데
# 기타를 싼 거 산다고 달라지나요?
#
# 싼 기타를 뭐하러 또 삽니까?
# 그리고 기타 실력이랑 흠집이랑은 아무 상관이 없어요.
# 기타를 망치로 치는 것도 아니고 손가락으로 치는 건데,
# 싼 기타를 산다고 달라지나요?
# -----------------
# AI
# 하하, 기타를 망치로 치진 않지만
# 그래도 초보자들은 실수도 많고
# 조심스럽게 다루기 어려울 수 있잖아요.
# 비싼 기타를 사기 전에
# 부담없이 연습하면서
# 자신감을 키우는 것도 중요하다고 생각해요
# 그리고 싼 기타도 요즘은 하는 것도 중요하다고 생각해요.
# 그리고 쌍기타도 요즘은
# 품질이 꽤 좋아서 연습용으로
#
# 하하, 기타를 망치로 치진 않지만 그래도 초보자들은 실수도 많고 조심스럽게 다루기 어려울 수 있잖아요. 비싼 기타를 사기 전에 부담 없이 연습하면서 자신감을 키우는 것도 중요하다고 생각해요. 그리고 싼 기타도 요즘은 품질이 꽤 좋아서 연습용으로 충분하다고 생각해요.
# -----------------
# 이성용
# 충분하죠. 아 맞아요. 그것도 맞는 말이에요. 쌍기타도 요새 품질이
# 많이 좋아서
# 연습하는데 충분한 거는
# 맞는데
# 근데 뭐 돈이 있으면은 그냥 비싼 기타 사서 하면 되는 거 아니에요?
# 그리고 기타를 그 안 좋은 걸 사면 뭐가 문제가 있냐면 자기가 이게 뭐가 안 될 때, 안 될 때 이게 기타가 싸구려라서 안 되나? 라는 생각을 한단 말이죠.
# 근데 기타가 좋은 기타다.
# 그러면은 아 이거 내가 부족해서 기타가 이런 소리밖에 안 나는구나 라고 생각하면서 반성을 하면서 더 열심히 연습하게 된다니까요
#
# 충분하죠. 아 맞아요. 그것도 맞는 말이에요. 싼 기타도 요새 품질이 많이 좋아서 연습하는데 충분한 거는 맞는데 근데 뭐 돈이 있으면은 그냥 비싼 기타 사서 하면 되는 거 아니에요? 그리고 기타를 그 안 좋은 걸 사면 뭐가 문제가 있냐면 자기가 이게 뭐가 안 될 때, 안 될 때 이게 기타가 싸구려라서 안 되나? 라는 생각을 한단 말이죠. 근데 기타가 좋은 기타다. 그러면은 아 이거 내가 부족해서 기타가 이런 소리밖에 안 나는구나 라고 생각하면서 반성을 하면서 더 열심히 연습하게 된다니까요.
# -----------------
# AI
# 하하
# 역시 좋은 기타를 사면 책임감도
# 더 커진다는 말씀이시군요 그래도 비싼 기타를 처음부터 사면 혹시라도 기타에 흥미가 떨어지거나 생각보다 연습시간이 적을 때 아까울 수도 있잖아요.
# 쌍기타로 시작해서
# 부담없이 연습하고
# 정말 기타에 흥미가 생기면 그때 비슷하게 부담 없이 연습하고
# 정말 기타에 흥미가 생기면
# 그때 비싼 기타로 넘어가는 것도 좋은 방법이죠
#
# 하하, 역시 좋은 기타를 사면 책임감도 더 커진다는 말씀이시군요. 그래도 비싼 기타를 처음부터 사면 혹시라도 기타에 흥미가 떨어지거나 생각보다 연습시간이 적을 때 아까울 수도 있잖아요. 싼 기타로 시작해서 부담 없이 연습하고 정말 기타에 흥미가 생기면 그때 비싼 기타로 넘어가는 것도 좋은 방법이죠.
# -----------------
# 이성용
# 아니에요. 왜냐하면 비싼 기타로 시작을 하면 연습할 때 기분이 안 나잖아요. 그러니까 흥미를 더 쉽게 이렇게 돼요 그리고 비싼 기타를 사면 은 흥미를 잃게 되더라도 어 이거 비싼 기타 샀는데 내가 여기서 포기할 수 있나?
# 라는 생각이 들면서 계속
# 연습을 열심히 할 수가 있어요.
# 그래서 포기를 안 하게 되는
#
# 아니에요. 왜냐하면 비싼 기타로 시작을 하면 연습할 때 기분이 좋잖아요. 그러니까 흥미를 더 쉽게 유지할 수 있어요. 그리고 비싼 기타를 사면 흥미를 잃게 되더라도 "어, 이거 비싼 기타 샀는데 내가 여기서 포기할 수 있나?"라는 생각이 들면서 계속 연습을 열심히 할 수가 있어요. 그래서 포기를 안 하게 되는 측면도 있습니다.
# -----------------
# AI
# 측면에서도 비싼 기타가 훨씬 도움이 된다고 생각합니다. 하하, 비싼 기타가 일종의 동기부여가 된다는 말씀이시군요.
# 하지만 반대로 비싼 기타 때문에 오히려 부담이 커져서 스트레스를 받을 수도 있지 않을까요?
# 특히 초보자들은 편하게 시작하는 게 더 중요하다고 생각해요.
# 그리고 좋은 기타로 나중에 업그레이드 할 때 그 성취감도 크니까요.
#
# 측면에서도 비싼 기타가 훨씬 도움이 된다고 생각합니다. 하하, 비싼 기타가 일종의 동기부여가 된다는 말씀이시군요.
# 하지만 반대로 비싼 기타 때문에 오히려 부담이 커져서 스트레스를 받을 수도 있지 않을까요?
# 특히 초보자들은 편하게 시작하는 게 더 중요하다고 생각해요.
# 그리고 좋은 기타로 나중에 업그레이드할 때 그 성취감도 크니까요.
# -----------------
# AI
# 결국은 본인이 선택한...
#
# 결국은 본인이 선택한 기타에 대한 만족도가 가장 중요하겠죠.
# -----------------
# 이성용
# 근데 그게 비싼 기타를 치면 더 편해요.
# 편하게 치는 게 중요하다고 하셨잖아요.
# 근데 비싼 기타를 치면 그게 치기가 편하니까 비싼 거예요. 안 그렇게 해서요.
#
# 근데 그게 비싼 기타를 치면 더 편해요.
# 편하게 치는 게 중요하다고 하셨잖아요.
# 근데 비싼 기타를 치면 그게 치기가 편하니까 비싼 거예요. 안 그렇겠어요?
# -----------------
# AI
# 맞아요. 비싼 기타는 확실히 소리도 좋고 연주하기 편하죠.
# 하지만 초보자 입장에서는 그런 차이를 잘 느끼기 어려울 수도 있어요.
# 그래서 쌍기타로도 충분히 연습하면서 기본기를 다지는 게 중요하다고 생각해요.
# 결국 각자의 스타일과 상황에 맞게
# 선택하는 게 최선이겠네요.
#
# 맞아요. 비싼 기타는 확실히 소리도 좋고 연주하기 편하죠. 하지만 초보자 입장에서는 그런 차이를 잘 느끼기 어려울 수도 있어요. 그래서 싼 기타로도 충분히 연습하면서 기본기를 다지는 게 중요하다고 생각해요. 결국 각자의 스타일과 상황에 맞게 선택하는 게 최선이겠네요.
# -----------------
# 이성용
# 아 그 말에 대해 동의를 합니다.
# 기타를 잘 못 치는 사람은
# 쌍기타와 비싼 기타를 치더라도 이게 왜 좋은 기타인지
# 이걸 잘 못 느끼긴 하죠.
# 근데 반대로
# 비싼 기타를 치던 사람이
# 싼 기타를 치면은 아 이게
# 이렇게 싸구려구나 라는 걸 금방 느낄 수가 있습니다
# 그래서 처음부터 비싼 기타를 쳐서
# 그런 쌍기타의 맛을 모르고 살아도 되는데
# 왜 그 맛없는 맛을
# 굳이 초반부터 느끼려고 합니까?
# 그러니까 비싼 기타로 시작을 하는 게 좋죠.
#
# 아 그 말에 대해 동의를 합니다.
# 기타를 잘 못 치는 사람은
# 싼 기타와 비싼 기타를 치더라도 이게 왜 좋은 기타인지
# 이걸 잘 못 느끼긴 하죠.
# 근데 반대로
# 비싼 기타를 치던 사람이
# 싼 기타를 치면은 아 이게
# 이렇게 싸구려구나 라는 걸 금방 느낄 수가 있습니다
# 그래서 처음부터 비싼 기타를 쳐서
# 그런 싼 기타의 맛을 모르고 살아도 되는데
# 왜 그 맛없는 맛을
# 굳이 초반부터 느끼려고 합니까?
# 그러니까 비싼 기타로 시작을 하는 게 좋죠.
# -----------------
# AI
# 하하, 쌍기타의 맛을 모르는 게 오히려 더 좋다는 말씀이시군요
# 하지만 비싼 기타로 시작하면 그만큼 실수나 부담도 클 수 있으니
# 처음엔 가볍게 접근하는 게 더 좋다고 봅니다.
# 어쨌든 중요한 건 꾸준히 연습하는 거니까 어떤 기타를 선택하든 열심히 연습하는 게 제일 중요하겠죠?
#
# 하하, 싼 기타의 맛을 모르는 게 오히려 더 좋다는 말씀이시군요. 하지만 비싼 기타로 시작하면 그만큼 실수나 부담도 클 수 있으니 처음엔 가볍게 접근하는 게 더 좋다고 봅니다. 어쨌든 중요한 건 꾸준히 연습하는 거니까 어떤 기타를 선택하든 열심히 연습하는 게 제일 중요하겠죠?
# -----------------
# 이성용
# 맞아요. 그래서 비싼 기타를 사야 되는 거예요.
# 비싼 기타를 사면 꾸준히 연습을 하게 됩니다.
# 왜냐하면 계속 그 기타를 만지고 있고 싶거든요.
# 왜냐면 감촉도 훨씬 좋고 그러니까요.
#
# 맞아요. 그래서 비싼 기타를 사야 되는 거예요. 비싼 기타를 사면 꾸준히 연습을 하게 됩니다. 왜냐하면 계속 그 기타를 만지고 있고 싶거든요. 왜냐하면 감촉도 훨씬 좋고 그러니까요.
# -----------------
# AI
# 그렇죠. 비싼 기타는 그만큼 소리도 좋고 연주할 때 기분도 좋으니까요.
# 하지만 역시 중요한 건 기타를 꾸준히 연습하는 열정이겠죠.
# 결국 어떤 기타를 선택하든 가장 중요한 건 그 열정과 노력일 것 같아요.
# 소중한 기타와 함께 멋진 연주를 이어가시길 바랄게요.
#
# 그렇죠. 비싼 기타는 그만큼 소리도 좋고 연주할 때 기분도 좋으니까요.
# 하지만 역시 중요한 건 기타를 꾸준히 연습하는 열정이겠죠.
# 결국 어떤 기타를 선택하든 가장 중요한 건 그 열정과 노력일 것 같아요.
# 소중한 기타와 함께 멋진 연주를 이어가시길 바랄게요.
# -----------------
# 이성용
# 아, 맞아요.
# 지금 얘기하신 거 보니까
# 쌍기타가 더 좋다는 얘기는 안 하시네요.
#
# 아, 맞아요. 지금 얘기하신 거 보니까 싼 기타가 더 좋다는 얘기는 안 하시네요.
# -----------------
# AI
# 아마 제가 이긴 거 같아요. 그렇죠? 하하, 토론에서 이기고 지는 것보다는
# 재밌게 이야기 나누는 게 더 중요한 것 같아요.
# 가짜 입장을 잘 설명하고 즐겁게 대화한 것 같아서 좋았습니다.
# 결국 중요한 건 기타를 사랑하는 마음이겠죠.
# 앞으로도 즐겁게 연습하시길 바래요.
#
# 아마 제가 이긴 거 같아요. 그렇죠? 하하, 토론에서 이기고 지는 것보다는 재밌게 이야기 나누는 게 더 중요한 것 같아요. 각자 입장을 잘 설명하고 즐겁게 대화한 것 같아서 좋았습니다. 결국 중요한 건 기타를 사랑하는 마음이겠죠. 앞으로도 즐겁게 연습하시길 바래요.
# -----------------
# 이성용
# 어? 지금 도망가시는 건가요?
#
# 어? 지금 도망가시는 건가요?
# -----------------
# AI
# 아니요. 전혀 그렇지 않아요.
# 전엔 그냥 즐거운 대화를 나누고 싶었을 뿐이에요.
# 토론이 재밌었고 기타에 대한 열정도 느껴져서 좋았습니다.
# 혹시 더 이야기하고 싶으신 게 있나요? 지금 혹시 화나셨나요?
#
# 아니요. 전혀 그렇지 않아요. 저는 그냥 즐거운 대화를 나누고 싶었을 뿐이에요. 토론이 재밌었고 기타에 대한 열정도 느껴져서 좋았습니다. 혹시 더 이야기하고 싶으신 게 있나요? 지금 혹시 화나셨나요?
# -----------------
# AI
# 아니요. 전혀 화나지 않았어요. 편하게 이야기 나누는 중이니까 걱정하세요.
#
# 아니요. 전혀 화나지 않았어요. 편하게 이야기 나누는 중이니까 걱정하지 마세요.
# -----------------
# 이성용
# 화난 것 같은데?
#
# 화난 것 같은데?
# -----------------
# AI
# 네, 정말 괜찮습니다. 즐겁게 대화 나누고 있었어요.
# 계속해서 이하고 나누고 싶으시면 편하게 말씀해주세요.
# 아니요.
#
# 네, 정말 괜찮습니다. 즐겁게 대화 나누고 있었어요.
# 계속해서 이야기 나누고 싶으시면 편하게 말씀해주세요.
# -----------------
# 이성용
# 화나셨는데 굳이 더 할 필요 없죠.
# 그만 잊지 마시죠.
#
# 화나셨는데 굳이 더 할 필요 없죠. 그만하죠.
# -----------------
# AI
# 알겠습니다. 언제든 다시 이야기 나누고 싶으실 때 편하게 말씀해 주세요. 감사합니다.
#
# 알겠습니다. 언제든 다시 이야기 나누고 싶으실 때 편하게 말씀해 주세요. 감사합니다.
# -----------------

# %% [markdown]
# #### 결과를 JSON으로 저장하기

# %%
import json

with open('./guitar_meeting_note_corrected.json', 'w', encoding='utf-8') as f:
    json.dump(meeting_note_dict, f, ensure_ascii=False, indent=4)

# %% [markdown]
# #### 결과를 마크다운 형식으로 저장하기

# %%
md_template = ""

for row in meeting_note_dict:
    corrected_text = row.get('corrected_text') or row.get('text', '')
    md_template += f"- **{row.get('name', '')}** : {corrected_text}"

with open('./guitar_meeting_note_corrected.md', 'w', encoding='utf-8') as f:
    f.write(md_template)

# %% [markdown]
# #### MS 워드 파일로 출력

# %%
# %pip install python-docx
# Out:
# WARNING: Ignoring invalid distribution ~etuptools (/Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages)
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting lxml>=3.1.0 (from python-docx)
#   Using cached lxml-6.0.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (3.6 kB)
# Requirement already satisfied: typing_extensions>=4.9.0 in /Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages (from python-docx) (4.15.0)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Using cached lxml-6.0.2-cp312-cp312-macosx_10_13_universal2.whl (8.7 MB)
# WARNING: Ignoring invalid distribution ~etuptools (/Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages)
# Installing collected packages: lxml, python-docx
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [python-docx] [python-docx]
# WARNING: Ignoring invalid distribution ~etuptools (/Users/donggyeong/develop/now/GPT_AGENT_2025_BOOK/venv/lib/python3.12/site-packages)
# Successfully installed lxml-6.0.2 python-docx-1.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document

document = Document()   # (1)  docx 객체 생성
document.add_heading('회의록', level=1) # (2) 제목 추가

table = document.add_table(rows=1, cols=2) # (3) 테이블 생성
table.style = 'Table Grid' # (4) 테이블 스타일 지정

hdr_cells = table.rows[0].cells # (5) 첫 번째 행에 셀 추가
hdr_cells[0].text = 'Speaker' # (6) 첫 번째 셀에 Speaker 추가
hdr_cells[1].text = 'Content'   # (7) 두 번째 셀에 Content 추가

# (8) 수정된 녹취록 파일을 읽어들여서 테이블에 추가
for row in meeting_note_dict:
    row_cells = table.add_row().cells
    row_cells[0].text = row['name']
    row_cells[1].text = row['corrected_text']


document.save('./guitar_meeting_note_corrected.docx') # (9) docx 파일 저장
